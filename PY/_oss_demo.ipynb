# %%
import os

# %%
os.name
# Out:
# 'nt'

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\26856\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_38080_BAFTOKEPANDIFGLH',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': '王周宇的笔记本',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\26856',
#         'LOCALAPPDATA': 'C:\\Users\\26856\\AppData\\Local',
#         'LOGONSERVER': '\\\\王周宇的笔记本',
#         'NUMBER_OF_PROCESSORS': '8',
#         'ONEDRIVE': 'C:\\Users\\26856\\OneDrive',
# ...

# %%
for k,v in os.environ.items():
    print(k,v)
# Out:
# ALLUSERSPROFILE C:\ProgramData
# APPDATA C:\Users\26856\AppData\Roaming
# CHROME_CRASHPAD_PIPE_NAME \\.\pipe\LOCAL\crashpad_38080_BAFTOKEPANDIFGLH
# COMMONPROGRAMFILES C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86) C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432 C:\Program Files\Common Files
# COMPUTERNAME 王周宇的笔记本
# COMSPEC C:\WINDOWS\system32\cmd.exe
# DRIVERDATA C:\Windows\System32\Drivers\DriverData
# FPS_BROWSER_APP_PROFILE_STRING Internet Explorer
# FPS_BROWSER_USER_PROFILE_STRING Default
# HOMEDRIVE C:
# HOMEPATH \Users\26856
# LOCALAPPDATA C:\Users\26856\AppData\Local
# LOGONSERVER \\王周宇的笔记本
# NUMBER_OF_PROCESSORS 8
# ONEDRIVE C:\Users\26856\OneDrive
# ONEDRIVECONSUMER C:\Users\26856\OneDrive
# ORIGINAL_XDG_CURRENT_DESKTOP undefined
# OS Windows_NT
# ...

# %%
import sys

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  'encodings': <module 'encodings' from 'c:\\vnstudio\\lib\\encodings\\__init__.py'>,
#  'codecs': <module 'codecs' from 'c:\\vnstudio\\lib\\codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'c:\\vnstudio\\lib\\encodings\\aliases.py'>,
# ...
